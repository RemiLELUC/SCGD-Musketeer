# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Load results

# %%
losses_mnist_uni = np.load('losses_zo_mnist_uni.npy')
losses_mnist_avg = np.load('losses_zo_mnist_avg.npy')
losses_mnist_nes = np.load('losses_zo_mnist_nes.npy')
losses_mnist_sqr = np.load('losses_zo_mnist_sqr.npy')
losses_mnist_abs = np.load('losses_zo_mnist_abs.npy')

# %%
l_uni = losses_mnist_uni[:,::1875]
mean_uni = np.mean(l_uni,axis=0)
std_uni = np.std(l_uni,axis=0)

l_avg = losses_mnist_avg[:,::1875]
mean_avg = np.mean(l_avg,axis=0)
std_avg = np.std(l_avg,axis=0)

l_sqr = losses_mnist_sqr[:,::1875]
mean_sqr = np.mean(l_sqr,axis=0)
std_sqr = np.std(l_sqr,axis=0)

l_abs = losses_mnist_abs[:,::1875]
mean_abs = np.mean(l_abs,axis=0)
std_abs = np.std(l_abs,axis=0)

l_nes = losses_mnist_nes[:,::1875]
mean_nes = np.mean(l_nes,axis=0)
std_nes = np.std(l_nes,axis=0)

# %% [markdown]
# ### Plot MNIST

# %%
fig,ax = plt.subplots(figsize=(8,6))
plt.plot(mean_uni,color='k',linestyle='dashdot',label='uniform')
plt.plot(mean_nes,color='purple',marker='p',markevery=0.1,ms=4,label='nesterov')
plt.plot(mean_avg,color='b',marker='s',markevery=0.1,ms=4,label='mus_avg')
plt.plot(mean_sqr,color='red',marker='v',markevery=0.1,ms=4,label='mus_sqr')
plt.plot(mean_abs,color='green',marker='o',markevery=0.1,ms=4,label='mus_abs')

plt.fill_between(np.arange(100),
                 mean_uni-std_uni/2,
                 mean_uni+std_uni/2,
                 color='k',alpha=0.2)

plt.fill_between(np.arange(100),
                 mean_nes-std_nes/2,
                 mean_nes+std_nes/2,
                 color='purple',alpha=0.2)

plt.fill_between(np.arange(100),
                 mean_avg-std_avg/2,
                 mean_avg+std_avg/2,
                 color='b',alpha=0.2)

plt.fill_between(np.arange(100),
                 mean_sqr-std_sqr/2,
                 mean_sqr+std_sqr/2,
                 color='red',alpha=0.2)

plt.fill_between(np.arange(100),
                 mean_abs-std_abs/2,
                 mean_abs+std_abs/2,
                 color='green',alpha=0.2)

#plt.yscale('log')
#plt.xscale('symlog')
plt.ylabel(r'Training Loss',fontsize=15)
plt.xlabel('#Queries of Loss f (x1e3)',fontsize=15)
plt.xticks(ticks=[0,20,40,60,80,100],labels=['0','75','150','225','300','375'],fontsize=15)
plt.yticks(fontsize=15)
#plt.legend(fontsize=15)
#plt.legend(loc='lower left',fontsize=15)
plt.legend(loc='upper right',fontsize=15)
plt.grid(linestyle='--',which='both',alpha=0.5)
#plt.title('Ridge Regression',fontsize=15)
plt.tight_layout()
ax.spines["right"].set_visible(False)
ax.spines["top"].set_visible(False)
plt.show()

# %%
60000/32
# Out:
# 1875.0

# %% [markdown]
# 1 epoch = 1 pass sur toutes les données de train = 1875 batch de 32 images = 60,000 images

# %%
1875*2
# Out:
# 3750

# %% [markdown]
# 3750 queries by epoch

# %%
3750*np.array([0,20,40,60,80,100])
# Out:
# array([     0,  75000, 150000, 225000, 300000, 375000])

# %%
#np.save('losses_zo_mnist_uni.npy',losses_mnist_uni)
